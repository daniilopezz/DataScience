# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from IPython.display import Image as PImage
from subprocess import check_call
from PIL import Image, ImageDraw, ImageFont

# %%
futbol = pd.read_csv('SP1.csv')
# miramos la cantidad de lineas que tiene el archivo
futbol.shape
# Out:
# (300, 131)

# %%
# vemos la cabecera del archivo
futbol.head()
# Out:
#    Div        Date   Time    HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  SP1  15/08/2025  18:00      Girona  Vallecano     1     3   A     0     3
# 1  SP1  15/08/2025  20:30  Villarreal     Oviedo     2     0   H     2     0
# 2  SP1  16/08/2025  18:30    Mallorca  Barcelona     0     3   A     0     2
# 3  SP1  16/08/2025  20:30      Alaves    Levante     2     1   H     1     0
# 4  SP1  16/08/2025  20:30    Valencia   Sociedad     1     1   D     0     0
#
#    ... B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  \
# 0  ...      2.1      1.78   1.97   1.95     2.10     1.80     1.95     1.75
# 1  ...      1.9      1.95   1.93   2.00     1.94     1.96     1.82     1.87
# 2  ...      2.0      1.85   1.88   2.05     2.00     1.93     1.90     1.86
# 3  ...      1.8      2.05   1.86   2.07     1.80     2.07     1.70     2.00
# 4  ...      2.1      1.78   2.13   1.81     2.10     1.78     1.96     1.74
#
#    BFECAHH  BFECAHA
# 0     2.11     1.89
# 1     1.96     2.02
# 2     2.04     1.94
# 3     1.81     2.20
# 4     2.18     1.84
#
# [5 rows x 131 columns]

# %%
# hacemos una clasificacion por los equipos que han jugado en casa
futbol.groupby('HomeTeam').size()
# Out:
# HomeTeam
# Alaves         15
# Ath Bilbao     15
# Ath Madrid     16
# Barcelona      15
# Betis          15
# Celta          15
# Elche          15
# Espanol        15
# Getafe         15
# Girona         15
# Levante        15
# Mallorca       15
# Osasuna        14
# Oviedo         15
# Real Madrid    15
# Sevilla        15
# Sociedad       15
# Valencia       15
# Vallecano      15
# Villarreal     15
# dtype: int64
